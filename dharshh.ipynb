# %% [markdown]
# <a href="https://colab.research.google.com/github/Dharshithaa/Dharshithaa/blob/main/dharshh.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
#Importing libraries

# %%
import pandas as pd
#importing libraries

# %% [markdown]
# #Loading of data

# %%
from google.colab import drive
drive.mount('/content/drive')
#Mounting with Google drive
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
train = pd.read_csv('/content/drive/MyDrive/DataSets/Big_Mart Dataset/Train.csv')
test = pd.read_csv('/content/drive/MyDrive/DataSets/Big_Mart Dataset/Test.csv')
#importing libraries and loading the necessary dataset

# %% [markdown]
# #Data structures and Content

# %%
train.dtypes
#to display the data types of all columns
# Out:
# Item_Identifier               object
# Item_Weight                  float64
# Item_Fat_Content              object
# Item_Visibility              float64
# Item_Type                     object
# Item_MRP                     float64
# Outlet_Identifier             object
# Outlet_Establishment_Year      int64
# Outlet_Size                   object
# Outlet_Location_Type          object
# Outlet_Type                   object
# Item_Outlet_Sales            float64
# dtype: object

# %%
test.dtypes
#to display the data types of all columns
# Out:
# Item_Identifier               object
# Item_Weight                  float64
# Item_Fat_Content              object
# Item_Visibility              float64
# Item_Type                     object
# Item_MRP                     float64
# Outlet_Identifier             object
# Outlet_Establishment_Year      int64
# Outlet_Size                   object
# Outlet_Location_Type          object
# Outlet_Type                   object
# dtype: object

# %%
train.shape
#This will return the number of rows and the number of columns in the dataset
# Out:
# (8523, 12)

# %%
test.shape
#This will return the number of rows and the number of columns in the dataset
# Out:
# (5681, 11)

# %%
train.columns
#This will return an index object containig the column names of the dataset
# Out:
# Index(['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Visibility',
#        'Item_Type', 'Item_MRP', 'Outlet_Identifier',
#        'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type',
#        'Outlet_Type', 'Item_Outlet_Sales'],
#       dtype='object')

# %%
test.columns
#This will return an index object containig the column names of the dataset
# Out:
# Index(['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Visibility',
#        'Item_Type', 'Item_MRP', 'Outlet_Identifier',
#        'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type',
#        'Outlet_Type'],
#       dtype='object')

# %%
train.info()
#This will provide a detailed overview of the dataset's structure
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                7060 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                6113 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB

# %%
test.info()
#This will provide a detailed overview of the dataset's structure
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5681 entries, 0 to 5680
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            5681 non-null   object
#  1   Item_Weight                4705 non-null   float64
#  2   Item_Fat_Content           5681 non-null   object
#  3   Item_Visibility            5681 non-null   float64
#  4   Item_Type                  5681 non-null   object
#  5   Item_MRP                   5681 non-null   float64
#  6   Outlet_Identifier          5681 non-null   object
#  7   Outlet_Establishment_Year  5681 non-null   int64
#  8   Outlet_Size                4075 non-null   object
#  9   Outlet_Location_Type       5681 non-null   object
#  10  Outlet_Type                5681 non-null   object
# dtypes: float64(3), int64(1), object(7)
# memory usage: 488.3+ KB

# %%
train.head()
#To display the first few rows of the dataset
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
test.head()
#To display the first few rows of the dataset
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility    Item_Type  \
# 0           FDW58       20.750          Low Fat         0.007565  Snack Foods
# 1           FDW14        8.300              reg         0.038428        Dairy
# 2           NCN55       14.600          Low Fat         0.099575       Others
# 3           FDQ58        7.315          Low Fat         0.015388  Snack Foods
# 4           FDY38          NaN          Regular         0.118599        Dairy
#
#    Item_MRP Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# 0  107.8622            OUT049                       1999      Medium
# 1   87.3198            OUT017                       2007         NaN
# 2  241.7538            OUT010                       1998         NaN
# 3  155.0340            OUT017                       2007         NaN
# 4  234.2300            OUT027                       1985      Medium
#
#   Outlet_Location_Type        Outlet_Type
# ...

# %%
train.tail()
#To display the last few rows of a dataset
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 8518         Snack Foods  214.5218            OUT013
# 8519        Baking Goods  108.1570            OUT045
# 8520  Health and Hygiene   85.1224            OUT035
# 8521         Snack Foods  103.1332            OUT018
# 8522         Soft Drinks   75.4670            OUT046
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 8518                       1987        High               Tier 3
# 8519                       2002         NaN               Tier 2
# ...

# %%
test.tail()
#To display the last few rows of a dataset
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 5676           FDB58         10.5          Regular         0.013496
# 5677           FDD47          7.6          Regular         0.142991
# 5678           NCO17         10.0          Low Fat         0.073529
# 5679           FDJ26         15.3          Regular         0.000000
# 5680           FDU37          9.5          Regular         0.104720
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 5676         Snack Foods  141.3154            OUT046
# 5677       Starchy Foods  169.1448            OUT018
# 5678  Health and Hygiene  118.7440            OUT045
# 5679              Canned  214.6218            OUT017
# 5680              Canned   79.7960            OUT045
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 5676                       1997       Small               Tier 1
# 5677                       2009      Medium               Tier 3
# ...

# %%
train.duplicated()
#To identify duplicate rows in a dataset
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 8518    False
# 8519    False
# 8520    False
# 8521    False
# 8522    False
# Length: 8523, dtype: bool

# %%
test.duplicated()
#To identify duplicate rows in a dataset
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 5676    False
# 5677    False
# 5678    False
# 5679    False
# 5680    False
# Length: 5681, dtype: bool

# %%
train.describe()
#To generate descriptive statistics for the numerical columns of a dataset
# Out:
#        Item_Weight  Item_Visibility     Item_MRP  Outlet_Establishment_Year  \
# count  7060.000000      8523.000000  8523.000000                8523.000000
# mean     12.857645         0.066132   140.992782                1997.831867
# std       4.643456         0.051598    62.275067                   8.371760
# min       4.555000         0.000000    31.290000                1985.000000
# 25%       8.773750         0.026989    93.826500                1987.000000
# 50%      12.600000         0.053931   143.012800                1999.000000
# 75%      16.850000         0.094585   185.643700                2004.000000
# max      21.350000         0.328391   266.888400                2009.000000
#
#        Item_Outlet_Sales
# count        8523.000000
# mean         2181.288914
# std          1706.499616
# min            33.290000
# 25%           834.247400
# 50%          1794.331000
# 75%          3101.296400
# max         13086.964800

# %%
test.describe()
#To generate descriptive statistics for the numerical columns of a dataset
# Out:
#        Item_Weight  Item_Visibility     Item_MRP  Outlet_Establishment_Year
# count  4705.000000      5681.000000  5681.000000                5681.000000
# mean     12.695633         0.065684   141.023273                1997.828903
# std       4.664849         0.051252    61.809091                   8.372256
# min       4.555000         0.000000    31.990000                1985.000000
# 25%       8.645000         0.027047    94.412000                1987.000000
# 50%      12.500000         0.054154   141.415400                1999.000000
# 75%      16.700000         0.093463   186.026600                2004.000000
# max      21.350000         0.323637   266.588400                2009.000000

# %%
train.isnull().sum()
#To check for missing values in each column of a dataset
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
test.isnull().sum()
#To check for missing values in each column of a dataset
# Out:
# Item_Identifier                 0
# Item_Weight                   976
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  1606
# Outlet_Location_Type            0
# Outlet_Type                     0
# dtype: int64

# %% [markdown]
# #DATA PREPROCESSING

# %%
train['Item_Fat_Content'].value_counts()
#Display value counts for Item_Fat_Content
# Out:
# Item_Fat_Content
# Low Fat    5089
# Regular    2889
# LF          316
# reg         117
# low fat     112
# Name: count, dtype: int64

# %%
 train['Item_Fat_Content'].replace(['LF','low fat','reg'],['Low Fat','Low Fat','Regular'],inplace=True)
#Replacing inconsistent values

# %%
train['Item_Fat_Content'].value_counts()
#To display the value counts
# Out:
# Item_Fat_Content
# Low Fat    5517
# Regular    3006
# Name: count, dtype: int64

# %%
test['Item_Fat_Content'].value_counts()
#To display the value count of Item_Fat_Content
# Out:
# Item_Fat_Content
# Low Fat    3396
# Regular    1935
# LF          206
# reg          78
# low fat      66
# Name: count, dtype: int64

# %%
test['Item_Fat_Content'].replace(['LF','low fat','reg'],['Low Fat','Low Fat','Regular'],inplace=True)
#Replacing inconsistent values

# %%
test['Item_Fat_Content'].value_counts()
#Display the value count
# Out:
# Item_Fat_Content
# Low Fat    3668
# Regular    2013
# Name: count, dtype: int64

# %% [markdown]
# #Exploratory Data Analysis

# %% [markdown]
# Uni variate analysis

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import colors
#importing libraries for graphical representation

# %%
plt.figure(figsize=(3,3))
sns.countplot(x='Item_Fat_Content',data=train)
plt.xlabel('Item_Fat_Content')
plt.show()
# A countplot is a type of data visualization used in python.
# It is particularly useful for visualising the count occurences of each unique value.
# The sns.countplot function is used to create the count plot.
# The items have more low fat content and moderate regular fat content.

# %% [markdown]
# Low fat is high in count.
#
# Regular is low in count.

# %%
plt.figure(figsize=(3,3))
sns.countplot(y='Item_Type',data=train)
plt.ylabel('Item_Type')
plt.show()

# %% [markdown]
# Fruits and vegetables is leading in count.
# Snacks foods is next to it.
# Seafood is least in count.

# %%
outletsize=train['Outlet_Size'].value_counts(normalize=True)*100
explode=(0.05,0.06,0.07)
colors=('blue','black','red')
plt.pie(outletsize,labels=outletsize.index,autopct='%1.1f%%',explode=explode,colors=colors)
plt.title('percentage of outletsize')
plt.axis('equal')
plt.show()

# %% [markdown]
# Medium sized outlet is more in number.
# High outlet size is less in number.

# %%
plt.figure(figsize=(3,3))
sns.countplot(y='Outlet_Type',data=train)
plt.ylabel('Outlet_Type')
plt.show()

# %% [markdown]
# Supermarket type 1 is higher in count
# Supermarket type 3 is less in count when compared to others

# %%
plt.figure(figsize=(3,3))
sns.countplot(x='Outlet_Location_Type',data=train)
plt.xlabel('Outlet_Loction_Type')
plt.show()

# %% [markdown]
# Tier 3 Outlet loction type is high in count.Next to it tier 2 oulet location type is high in count.Tier 1 outlet type is least in count

# %%
plt.figure(figsize=(3,3))
sns.countplot(y='Outlet_Type',data=train)
plt.ylabel('Outlet_Type')
plt.show()

# %% [markdown]
# supermarket type 1 is high in count.
# supermarket type 3 is low in count.

# %% [markdown]
# #To Handle The Missing And Categorical values

# %%
# To handle the Missing and null values
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()
for col in train.columns:
  if train[col].dtype=='object':
    train[col]=le.fit_transform(train[col])

# %%
train['Outlet_Size'].dtypes
#to display the datatype of the outletsize dataset
# Out:
# dtype('int64')

# %%
train.head()
#to display the first five rows of the dataset
# Out:
#    Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  Item_Type  \
# 0              156         9.30                 0         0.016047          4
# 1                8         5.92                 1         0.019278         14
# 2              662        17.50                 0         0.016760         10
# 3             1121        19.20                 1         0.000000          6
# 4             1297         8.93                 0         0.000000          9
#
#    Item_MRP  Outlet_Identifier  Outlet_Establishment_Year  Outlet_Size  \
# 0  249.8092                  9                       1999            1
# 1   48.2692                  3                       2009            1
# 2  141.6180                  9                       1999            1
# 3  182.0950                  0                       1998            3
# 4   53.8614                  1                       1987            0
#
#    Outlet_Location_Type  Outlet_Type  Item_Outlet_Sales
# ...

# %%
imputer=SimpleImputer(strategy='mean')
missing_columns=['Item_Weight','Outlet_Size']
train[missing_columns]=imputer.fit_transform(train[missing_columns])

# %%
train.isnull().sum()
#To display the null values in the dataset
# Out:
# Item_Identifier              0
# Item_Weight                  0
# Item_Fat_Content             0
# Item_Visibility              0
# Item_Type                    0
# Item_MRP                     0
# Outlet_Identifier            0
# Outlet_Establishment_Year    0
# Outlet_Size                  0
# Outlet_Location_Type         0
# Outlet_Type                  0
# Item_Outlet_Sales            0
# dtype: int64

# %%
le=LabelEncoder()
for col in test.columns:
  if test[col].dtype=='object':
    test[col]=le.fit_transform(test[col])

# %%
test['Outlet_Size'].dtypes
#To display the datatype of outlet size in the dataset
# Out:
# dtype('int64')

# %%
test.head()
#To display the first five rows in the dataset
# Out:
#    Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  Item_Type  \
# 0             1103       20.750                 0         0.007565         13
# 1             1067        8.300                 1         0.038428          4
# 2             1406       14.600                 0         0.099575         11
# 3              809        7.315                 0         0.015388         13
# 4             1184          NaN                 1         0.118599          4
#
#    Item_MRP  Outlet_Identifier  Outlet_Establishment_Year  Outlet_Size  \
# 0  107.8622                  9                       1999            1
# 1   87.3198                  2                       2007            3
# 2  241.7538                  0                       1998            3
# 3  155.0340                  2                       2007            3
# 4  234.2300                  5                       1985            1
#
#    Outlet_Location_Type  Outlet_Type
# ...

# %%
imputer=SimpleImputer(strategy='mean')
#Create simple imputer object for mean imputation in the test set
missing_columns=['Item_Weight','Outlet_Size']
#select columns with missing values
test[missing_columns]=imputer.fit_transform(test[missing_columns])
#Impute missing values in the selected column

# %%
test.isnull().sum()
#to display the null values in the dataset
# Out:
# Item_Identifier              0
# Item_Weight                  0
# Item_Fat_Content             0
# Item_Visibility              0
# Item_Type                    0
# Item_MRP                     0
# Outlet_Identifier            0
# Outlet_Establishment_Year    0
# Outlet_Size                  0
# Outlet_Location_Type         0
# Outlet_Type                  0
# dtype: int64

# %% [markdown]
# #Handling outliers

# %%
number_columns=train.select_dtypes(include=['int64','float64'])
fig,ax=plt.subplots(figsize=(10,5))
number_columns.boxplot(ax=ax,vert=False,color='blue')
plt.title('identifyig outliers')
plt.show()
# Create a horizontal boxplot for numerical columns in the DataFrame to identify outliers

# %% [markdown]
# The image shows a boxplot visualization of various features in a dataset, used to identify outliers. The features are listed on the y-axis, such as Item_Outlet_Sales, Outlet_Type, Item_MRP, etc., while the x-axis represents the values of these features. The boxplot highlights potential outliers in the dataset, particularly in the Item_Outlet_Sales feature, where there are several outliers extending far to the right. The code used for the visualization is visible above the plot, utilizing Python with libraries like Matplotlib for plotting.

# %%
number_columns=test.select_dtypes(include=['int64','float64'])
fig,ax=plt.subplots(figsize=(10,5))
number_columns.boxplot(ax=ax,vert=False,color='blue')
plt.title('identifyig outliers')
plt.show()
# Create a horizontal boxplot for numerical columns in the 'test' DataFrame to identify outliers

# %% [markdown]
# The image is a boxplot visualization showing the distribution and potential outliers of various features in a dataset. The y-axis lists features such as Outlet_Type, Item_MRP, and Item_Weight, while the x-axis represents their values. The plot highlights the presence of outliers in certain features, like Outlet_Establishment_Year and Item_Weight. The boxplots are oriented horizontally, and most features show a compact distribution of values with minimal outliers.

# %% [markdown]
# In the above graph,for test dataset there is only 3 outliers exists in range .

# %% [markdown]
# There is no outliers lies out of the range.

# %%
q1=np.percentile(train['Item_Outlet_Sales'], 25)
q3=np.percentile(train['Item_Outlet_Sales'], 75)
iqr=q3-q1
print('q1=',q1)
print('q3=',q3)
print('IQR=',iqr)
# Out:
# q1= 834.2474
# q3= 3101.2964
# IQR= 2267.049

# %%
upperlimit=q3+1.5*iqr
lowerlimit=q1-1.5*iqr
print('upperlimit',upperlimit)
print('lowerlimit',lowerlimit)
# Upper limit for outliers
# Lower limit for outliers
# Out:
# upperlimit 6501.8699
# lowerlimit -2566.3261

# %% [markdown]
# #cube transformation

# %%
train['Outlet_Sales_Cube']=np.cbrt(train['Item_Outlet_Sales'])
# Apply the cube root transformation to the 'Item_Outlet_Sales' column and create a new column 'Outlet_Sales_Cube' in the 'train' dataset

# %%
number_columns=train.select_dtypes(include=['int64','float64'])
fig,ax=plt.subplots(figsize=(10,5))
number_columns.boxplot(ax=ax,vert=False,color='blue')
plt.title('identifyig outliers')
plt.show()
# Create a horizontal boxplot for numerical columns in the 'train' DataFrame to identify outliers

# %% [markdown]
# #Square Transformation

# %%
train['Outlet_Sales_Square']=np.square(train['Item_Outlet_Sales'])
# Computes the square root of the sales data.

# %%
sns.distplot(a=train['Outlet_Sales_Square'],kde=True,rug=True)
 #a=train['Outlet_Sales_square']: Specifies the data to be plotted, which in this case is the Outlet_Sales_square column from the train DataFrame.
#kde=True: Adds a Kernel Density Estimate (KDE) line to the plot, which represents the probability density function of the data.
#rug=True: Adds small vertical lines at the bottom of the plot for each data point, giving a sense of the distribution of individual data points.
# Out:
# <ipython-input-54-d3147acc5752>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(a=train['Outlet_Sales_Square'],kde=True,rug=True)
# <Axes: xlabel='Outlet_Sales_Square', ylabel='Density'>

# %%
number_columns=train.select_dtypes(include=['int64','float64'])
fig,ax=plt.subplots(figsize=(10,5))
number_columns.boxplot(ax=ax,vert=False,color='blue')
plt.title('identifyig outliers')
plt.show()
# Selects numerical columns from the DataFrame and plots a horizontal boxplot to help identify outliers.

# %% [markdown]
# #Bivariate Analysis

# %%
sns.distplot(a=train['Item_Outlet_Sales'],kde=True,rug=True)
# Plotting the distribution of the 'Item_Outlet_Sales' column
# Out:
# <ipython-input-56-0ae58fe2382e>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(a=train['Item_Outlet_Sales'],kde=True,rug=True)
# <Axes: xlabel='Item_Outlet_Sales', ylabel='Density'>

# %% [markdown]
# The image shows a histogram with a kernel density estimate (KDE) plot overlaid. The x-axis represents
# "Item_Outlet_Sales" with values ranging from 0 to 14,000, and the y-axis shows the density. The distribution is
# right-skewed, with most sales clustered between 0 and 4,000, gradually tapering off toward higher sales values.

# %%
sns.distplot(a=train['Outlet_Sales_Cube'],kde=True,rug=True)
# Plotting the distribution of the 'Outlet_Sales_Cube' column
# Out:
# <ipython-input-57-b60465752a04>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(a=train['Outlet_Sales_Cube'],kde=True,rug=True)
# <Axes: xlabel='Outlet_Sales_Cube', ylabel='Density'>

# %% [markdown]
# The outliers ranging from 5 to 21 whereas the outliers also present in the range of 21-23 in the plentier amount

# %% [markdown]
# #Multivariate Analysis

# %%
# Subset the dataset to include only the relevant columns
subset = train[['Item_Weight', 'Item_Fat_Content', 'Item_Visibility', 'Item_Type', 'Item_MRP',
             'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type', 'Outlet_Type',
             'Item_Outlet_Sales','Outlet_Sales_Cube']]

# Calculate the correlation matrix
corr = subset.corr()

# Create a mask for the upper triangle of the heatmap
mask = np.triu(np.ones_like(corr, dtype=bool))

# Set up the figure and axis objects
fig, ax = plt.subplots(figsize=(10, 8))

# Generate the heatmap with green and white colors
sns.heatmap(corr, mask=mask, annot=True, cmap=sns.diverging_palette(20, 220, n=200),
            center=0, square=True, linewidths=.5, cbar_kws={"shrink": .5})

# Set the title and labels for the plot
ax.set_title("Correlation Heatmap", fontsize=18)
ax.set_xlabel("Features", fontsize=14)
ax.set_ylabel("Features", fontsize=14)

# Show the plot
plt.show()

# %% [markdown]
# #Future Engineering

# %%
train.head()
#to display the first five rows of the dataset
# Out:
#    Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  Item_Type  \
# 0              156         9.30                 0         0.016047          4
# 1                8         5.92                 1         0.019278         14
# 2              662        17.50                 0         0.016760         10
# 3             1121        19.20                 1         0.000000          6
# 4             1297         8.93                 0         0.000000          9
#
#    Item_MRP  Outlet_Identifier  Outlet_Establishment_Year  Outlet_Size  \
# 0  249.8092                  9                       1999          1.0
# 1   48.2692                  3                       2009          1.0
# 2  141.6180                  9                       1999          1.0
# 3  182.0950                  0                       1998          3.0
# 4   53.8614                  1                       1987          0.0
#
# ...

# %%
train['Outlet_Age']=train['Outlet_Establishment_Year'].apply(lambda year: 2024-year)
#Calculate the age of each outlet from subtracting the establishment year from 2024
#And add it as a new column to the dataset

# %%
train.head()
#To display the first five rows
# Out:
#    Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  Item_Type  \
# 0              156         9.30                 0         0.016047          4
# 1                8         5.92                 1         0.019278         14
# 2              662        17.50                 0         0.016760         10
# 3             1121        19.20                 1         0.000000          6
# 4             1297         8.93                 0         0.000000          9
#
#    Item_MRP  Outlet_Identifier  Outlet_Establishment_Year  Outlet_Size  \
# 0  249.8092                  9                       1999          1.0
# 1   48.2692                  3                       2009          1.0
# 2  141.6180                  9                       1999          1.0
# 3  182.0950                  0                       1998          3.0
# 4   53.8614                  1                       1987          0.0
#
# ...

# %%
train=train.drop(['Item_Identifier','Item_Weight','Outlet_Identifier','Outlet_Establishment_Year','Outlet_Size','Outlet_Sales_Square'],axis=1)
#Remove the specified columns from the 'train' DataFrame.
#These columns are removed as they are not neccessary for the current analysis or modelling.

# %%
train=train.drop(['Item_Outlet_Sales','Item_Visibility'],axis=1)
#Remove the specified columns from the 'train' DataFrame.
#These columns are removed as they are not neccessary for the current analysis or modelling.

# %%
train.head()
#to display the first five rows
# Out:
#    Item_Fat_Content  Item_Type  Item_MRP  Outlet_Location_Type  Outlet_Type  \
# 0                 0          4  249.8092                     0            1
# 1                 1         14   48.2692                     2            2
# 2                 0         10  141.6180                     0            1
# 3                 1          6  182.0950                     2            0
# 4                 0          9   53.8614                     2            1
#
#    Outlet_Sales_Cube  Outlet_Age
# 0          15.515611          25
# 1           7.625576          15
# 2          12.800240          25
# 3           9.013888          26
# 4           9.982319          37

# %%
test['Outlet_Age']=test['Outlet_Establishment_Year'].apply(lambda year: 2024-year)
#Calculate the age of each outlet from subtracting the establishment year from 2024
#And add it as a new column to the dataset

# %%
test.head()
#to display the first five rows
# Out:
#    Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  Item_Type  \
# 0             1103    20.750000                 0         0.007565         13
# 1             1067     8.300000                 1         0.038428          4
# 2             1406    14.600000                 0         0.099575         11
# 3              809     7.315000                 0         0.015388         13
# 4             1184    12.695633                 1         0.118599          4
#
#    Item_MRP  Outlet_Identifier  Outlet_Establishment_Year  Outlet_Size  \
# 0  107.8622                  9                       1999          1.0
# 1   87.3198                  2                       2007          3.0
# 2  241.7538                  0                       1998          3.0
# 3  155.0340                  2                       2007          3.0
# 4  234.2300                  5                       1985          1.0
#
#    Outlet_Location_Type  Outlet_Type  Outlet_Age
# ...

# %%
test=test.drop(['Item_Identifier','Item_Weight','Outlet_Identifier','Outlet_Establishment_Year','Outlet_Size'],axis=1)
#Remove the specified columns from the 'test' DataFrame.
#These columns are removed as they are not neccessary for the current analysis or modelling.

# %%
test=test.drop(['Item_Visibility'],axis=1)
#Remove the specified columns from the 'test' DataFrame.
#These columns are removed as they are not neccessary for the current analysis or modelling.

# %%
test.head()
#to display the first five rows
# Out:
#    Item_Fat_Content  Item_Type  Item_MRP  Outlet_Location_Type  Outlet_Type  \
# 0                 0         13  107.8622                     0            1
# 1                 1          4   87.3198                     1            1
# 2                 0         11  241.7538                     2            0
# 3                 0         13  155.0340                     1            1
# 4                 1          4  234.2300                     2            3
#
#    Outlet_Age
# 0          25
# 1          17
# 2          26
# 3          17
# 4          39

# %%
from sklearn.preprocessing import StandardScaler
#import standardscaler from sklearn.preprocessing for feature standardization.
#standardscaler will be used to standardize features by removing the mean and scaling to unit variation.

# %%
x=train[['Item_Fat_Content','Item_Type','Item_Type','Outlet_Location_Type','Outlet_Type','Outlet_Age']]
y=train['Outlet_Sales_Cube']
#Define the feature variable X for the model
#Define the target variable Y for the model

# %%
x.shape
#display the dimensions of 'x' dataframe
# Out:
# (8523, 6)

# %%
scaler=StandardScaler()
#Create an instance of standard scalar for feature standardization

# %%
x=scaler.fit_transform(x)
#standardize the feature variable xby using the standard scalar

# %%
print(x)
#To display the X
# Out:
# [[-0.73814723 -0.76647929 -0.76647929 -1.36933384 -0.25265831 -0.13954076]
#  [ 1.35474328  1.6089627   1.6089627   1.09156913  1.00297245 -1.33410274]
#  [-0.73814723  0.6587859   0.6587859  -1.36933384 -0.25265831 -0.13954076]
#  ...
#  [-0.73814723  0.1836975   0.1836975  -0.13888236 -0.25265831 -0.73682175]
#  [ 1.35474328  1.3714185   1.3714185   1.09156913  1.00297245 -1.33410274]
#  [-0.73814723  1.6089627   1.6089627  -1.36933384 -0.25265831  0.09937163]]

# %%
x=pd.DataFrame(x)
#Converting to pandas dataframe

# %%
x.head()
#to display the first five rows of the train dataset
# Out:
#           0         1         2         3         4         5
# 0 -0.738147 -0.766479 -0.766479 -1.369334 -0.252658 -0.139541
# 1  1.354743  1.608963  1.608963  1.091569  1.002972 -1.334103
# 2 -0.738147  0.658786  0.658786 -1.369334 -0.252658 -0.139541
# 3  1.354743 -0.291391 -0.291391  1.091569 -1.508289 -0.020085
# 4 -0.738147  0.421242  0.421242  1.091569 -0.252658  1.293934

# %%
print(type(x))
#To display type X
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
x_test=test[['Item_Fat_Content','Item_Type','Item_Type','Outlet_Location_Type','Outlet_Type','Outlet_Age']]
y_test=test['Item_MRP']

# %%
x_test.shape
#To print the shape of 'x_test' to see its dimensions
# Out:
# (5681, 6)

# %%
scaler=StandardScaler()
#Initialize the standardscaler object to

# %%
x_test=scaler.fit_transform(x)
#Standardize the test data using the previous standardscaler

# %%
print(type(x_test))
#To display the type 'x_test' column
# Out:
# <class 'numpy.ndarray'>

# %%
print(x_test)
#To print the X_test to inspect the test data
# Out:
# [[-0.73814723 -0.76647929 -0.76647929 -1.36933384 -0.25265831 -0.13954076]
#  [ 1.35474328  1.6089627   1.6089627   1.09156913  1.00297245 -1.33410274]
#  [-0.73814723  0.6587859   0.6587859  -1.36933384 -0.25265831 -0.13954076]
#  ...
#  [-0.73814723  0.1836975   0.1836975  -0.13888236 -0.25265831 -0.73682175]
#  [ 1.35474328  1.3714185   1.3714185   1.09156913  1.00297245 -1.33410274]
#  [-0.73814723  1.6089627   1.6089627  -1.36933384 -0.25265831  0.09937163]]

# %%
x_test=pd.DataFrame(x)
#Covert x_test data into pandas

# %%
x_test.head()
#To display the first five rows of x_test
# Out:
#           0         1         2         3         4         5
# 0 -0.738147 -0.766479 -0.766479 -1.369334 -0.252658 -0.139541
# 1  1.354743  1.608963  1.608963  1.091569  1.002972 -1.334103
# 2 -0.738147  0.658786  0.658786 -1.369334 -0.252658 -0.139541
# 3  1.354743 -0.291391 -0.291391  1.091569 -1.508289 -0.020085
# 4 -0.738147  0.421242  0.421242  1.091569 -0.252658  1.293934

# %% [markdown]
# #Model Building

# %%
from sklearn.linear_model import LinearRegression
#for evaluating the model using metrics
from sklearn.metrics import r2_score as R2
from sklearn.metrics import mean_squared_error as MSE
from sklearn.metrics import mean_absolute_error as MAE
from sklearn.model_selection import cross_val_score as CVS

# %%
# Define the linear regression model
lr = LinearRegression()

# Train the model on the training data
lr.fit(x, y)

# Precting the model using the test set
y_predict = lr.predict(x)

# Evaluating the training set with the metric values

print("R-Square value on the training set: = ", lr.score(x,y))
print("----------------------------------------------------------------------------------------------")

# Use cross-validation to get the R-squared score
scores = CVS(lr, x, y, cv=5)
print('CV R-squared scores:', scores,"\n")
print('Average CV R-squared score:', np.mean(scores),"\n")
# Out:
# R-Square value on the training set: =  0.24317463972533726
# ----------------------------------------------------------------------------------------------
# CV R-squared scores: [0.23572452 0.24415291 0.22928818 0.22650884 0.26875959]
#
# Average CV R-squared score: 0.24088680769781287

# %%
import pickle
#import pickle module for serializing and deserializing python objects

# %%
Bigmart= "BigMart_Analysis.sav"
pickle.dump(lr, open(Bigmart,'wb'))
#Define file name for saving the model

# %% [markdown]
# #Summary

# %% [markdown]
# The Big Mart analysis project leverages machine learning to optimize sales forecasting by systematically processing and analyzing data. The process begins with
#
#
# 1.Loading of Data:
# The project begins by importing the dataset, ensuring that all relevant information is accessible and organized.
#
# 2.Data Structures and Content:
# Data is structured with product details, sales figures, and categorical variables for comprehensive analysis.
#
# 3.Data Preprocessing:
# Cleans and prepares data by addressing inconsistencies, missing values, and redundant information for accuracy.
#
# 4.Univariate Analysis:
# Analyzes individual variables to understand their distribution, central tendency, and variability within the dataset.
#
# 5.Handling Missing and Categorical Values:
# Imputes missing values and encodes categorical variables to ensure accurate and reliable model input.
#
# 6.Handling the Outliers:
# Identifies and manages outliers to reduce their impact and improve the model’s performance and accuracy.
#
# 7.Cube Transformation:
# Applies transformation techniques to stabilize variance and normalize data distributions for better analysis.
#
# 8.Bivariate Analysis:
# Examines relationships between pairs of variables to uncover significant correlations and dependencies.
#
# 9.Feature Engineering:
# Develops and modifies features to enhance the model’s ability to predict sales effectively.
#
# 10.Model Building:
# Constructs and fine-tunes machine learning models to accurately forecast sales and optimize predictions.
